# %% [markdown]
# # Installing Jupyter

# %% [markdown]
# Install Jupyter using pip or conda, and verify the installation.

# %%
# !pip install jupyter
# Out:
# /bin/bash: pip: command not found

# %%
# !jupyter --version

# %% [markdown]
# # Creating a New Notebook

# %% [markdown]
# Launch Jupyter and create a new notebook file.

# %% [markdown]
# # Running Code Cells

# %% [markdown]
# Write and execute Python code in code cells, including basic operations.

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# # Using Markdown Cells

# %% [markdown]
# Create and format text using Markdown in notebook cells.

# %% [markdown]
# This is a **bold** text and *italic* text.
#
# - Bullet point 1
# - Bullet point 2
#
# 1. Numbered list
# 2. Another item

# %% [markdown]
# # Saving and Exporting Notebooks

# %% [markdown]
# Save notebooks and export them to different formats like HTML or PDF.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)
print(X[:5])
print(y[:5])
